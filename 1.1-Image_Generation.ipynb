# %%
# Import requirements.

import os

from src.sky import Sky
from src.pupil import Pupil
from src.shot import Shot
from src import utils

config = __import__("0-Config")

# %% [markdown]
# ---
# # Example visualization

# %%
sky = Sky(N=config.N, nb_stars=config.nb_stars, fwhm=config.fwhm, mag=config.mag, mag_prob=config.mag_prob, noise_mag=config.noise_mag, noise_std=config.noise_std)
sky.show()

# %%
pupil = Pupil(config.N, config.pupil_radius, config.obstruction_radius, config.arms_count, config.arms_size, config.arms_angle)
pupil.show()

# %%
pupil.show_diffraction_profile()

# %%
shot = Shot(sky, pupil)
shot.show()

# %%
config.i = 1
filename = utils.format_filename(config.filename_format, config)
path = os.path.join(config.path, filename)

shot.save(path)

print(utils.format_image_to_xml(path, sky.stars, config.fwhm))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 5
#       2 filename = utils.format_filename(config.filename_format, config)
#       3 path = os.path.join(config.path, filename)
# ----> 5 shot.save(path)
#       7 print(utils.format_image_to_xml(path, sky.stars, config.fwhm))
#
# File c:\Users\vince\Documents\Dev\CompuPhys\Sextractor-driven-by-Machine-Learning\src\shot.py:32, in Shot.save(self, path)
#      30     os.makedirs(dir)
#      31 plt.savefig(path + ".png")
# ---> 32 json.dump(self.sky.stars, open(path + ".json", "w"))
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
# ...
